# %% [markdown]
# ## LLM based guidance
#
# This notebook is an LLM-based analysis tool. It uses a large language model to generate structured summaries and answers from user prompts, optionally grounded in domain context provided in the notebook.

# %%
# `openai` is now pre-installed in the cesm-lab-neon-custom image
# (added to requirements.txt). No pip install needed.
# Set OPENAI_API_KEY in your environment / .env before running the next cell.
import os
assert os.environ.get("OPENAI_API_KEY"), "Set OPENAI_API_KEY before running ask_llm"

# %%
from llm_interaction import ask_llm

print(ask_llm(
    "What is 19+23? Return only the number.",
    context="You are a strict assistant. Output only the final answer, nothing else.",
    temperature=0.0
))
# Out:
# 42
